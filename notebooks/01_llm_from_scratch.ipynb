# %% [markdown]
# <a href="https://colab.research.google.com/github/ZiadACM/LLM-From-Scratch/blob/main/notebooks/01_llm_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LLM From Scratch
#
# This notebook documents my process of building a small decoder-only language model from random initialization using PyTorch.
#
# The goal is not to build a competitive language model. The goal is to understand the internal mechanics of an LLM by implementing and inspecting the important components myself.

# %% [markdown]
# ## Phase 1 — Environment
#
# Before building the model, I will inspect the execution environment rather than assuming specific Python, PyTorch, CUDA, or GPU versions.

# %%
import sys
import platform

import torch

print("Python version:", sys.version)
print("Platform:", platform.platform())
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Platform: Linux-6.6.122+-x86_64-with-glibc2.35
# PyTorch version: 2.11.0+cpu
# CUDA available: False
